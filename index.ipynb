# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#NetworkX-Introduction---Lab" data-toc-modified-id="NetworkX-Introduction---Lab-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>NetworkX Introduction - Lab</a></span><ul class="toc-item"><li><span><a href="#Introduction" data-toc-modified-id="Introduction-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Introduction</a></span></li><li><span><a href="#Objectives" data-toc-modified-id="Objectives-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Objectives</a></span></li><li><span><a href="#Import-the-Data" data-toc-modified-id="Import-the-Data-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Import the Data</a></span></li><li><span><a href="#Creating-a-Graph" data-toc-modified-id="Creating-a-Graph-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Creating a Graph</a></span></li><li><span><a href="#Adding-Nodes" data-toc-modified-id="Adding-Nodes-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Adding Nodes</a></span></li><li><span><a href="#Adding-Edges" data-toc-modified-id="Adding-Edges-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Adding Edges</a></span></li><li><span><a href="#Visualizing-the-Graph" data-toc-modified-id="Visualizing-the-Graph-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Visualizing the Graph</a></span></li><li><span><a href="#Summary" data-toc-modified-id="Summary-1.8"><span class="toc-item-num">1.8&nbsp;&nbsp;</span>Summary</a></span></li></ul></li></ul></div>

# %% [markdown]
# # NetworkX Introduction - Lab
#
# ## Introduction
#
# In this lab, you'll practice some of the introductory skills for creating graphs using the NetworkX library introduced in the previous lesson. To do this, you'll create a graph to visualize users and businesses from yelp reviews.
#
# ## Objectives
#
# In this lab you will:
#
# - Create basic network graphs with networkx
# - Add nodes and edges to networkx graphs
# - Visualize network graphs with networkx
#
# ## Import the Data
#
# To start, import the data stored in the file `'Yelp_reviews.csv'`.

# %%
# Your code here
import pandas as pd
df = pd.read_csv('Yelp_reviews.csv')

df.head(3)
# Out:
#               business_id        date               review_id  stars  \
# 0  7SO_rX1F6rQEl-5s3wZxgQ  2011-10-03  GxaYFCprt-wyqO--vB4PHQ      4
# 1  K2_Hmmo5crTYWiT_1sWnfQ  2011-12-22  FSrIgThMfFIh__TubVQkxw      3
# 2  FeI75xIG8PF_XZ6P80gLBQ  2012-06-04  eeJ10gamdNebtq028i0BvA      3
#
#                                                 text    type  \
# 0  After my last review, somewhat scathing regard...  review
# 1  Ok, so I'm catching up on past-due reviews.  F...  review
# 2  I want to like Turf, but the food is just okay...  review
#
#                   user_id  cool  useful  funny
# 0  J3I2NClEbD1Xr8lOdjxlqQ     1       2      1
# 1  J3I2NClEbD1Xr8lOdjxlqQ     0       0      0
# 2  64YY0h0ZAR2nbzxbx0IwJg     2       1      0

# %% [markdown]
# ## Creating a Graph
#
# Now, create an initial graph!

# %%
# Your code here
import networkx as nx
G = nx.Graph()

# %% [markdown]
# ## Adding Nodes
#
# Create a node for each user and each business in the dataset. Networks with multiple node types like this are called **bimodal networks**.
#
# Optionally, go further by creating a list of colors for when you visualize the graph. If you do this, append the color "green" to your color list every time you add a user node and append the color "blue" to your color list every time you add a business node.

# %%
# Your code here
names = {}
node_color = []
for n, person in enumerate(df.user_id.unique()):
    name = 'User{}'.format(n)
    names[person] = name
    G.add_node(name)
    node_color.append('green')
for n, biz in enumerate(df.business_id.unique()):
    name = 'Business{}'.format(n)
    names[biz] = name
    G.add_node(name)
    node_color.append('blue')

# %% [markdown]
# ## Adding Edges
#
# Next, iterate through the dataset and create an edge between users and the businesses they have reviewed.

# %%
# Your code here

for row in df.index:
    user = df['user_id'][row]
    u_name = names[user]
    biz = df['business_id'][row]
    b_name = names[biz]
    G.add_edge(u_name, b_name)

# %% [markdown]
# ## Visualizing the Graph
#
# Finally, create a visualization of your network. If you chose to color your nodes, pass the list of colors through the optional `node_color` parameter.

# %%
# Your code here
# %matplotlib inline
nx.draw(G, with_labels=True, alpha=0.7, font_size=6, node_size=500, node_color=node_color)
# Out:
# /Users/Annika/anaconda3/envs/learn-env/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):

# %% [markdown]
# ## Summary
#
# Nice work! In this lab you created an initial network to visualize a bimodal network of businesses and yelp reviewers!
